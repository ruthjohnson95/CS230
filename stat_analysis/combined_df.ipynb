# %%
import pandas as pd
import os

# %%
pylint_path="/Users/nandini/Desktop/CS230/CS230/stat_analysis/pylintcsv/"
#benchmark_name=os.path.basename(pylint_path).split('_pylint.txt')[0]
#benchmark_name

directory = os.fsencode(pylint_path) 

dic = dict()

for file in os.listdir(directory): 
    filename = os.fsdecode(file) 
    benchmark_name = filename.split('_pylint.txt')[0]
    full_path = pylint_path + filename
    df = pd.read_csv(full_path)
    dic[benchmark_name] = df.sum()

# %%
pylint_df = pd.DataFrame.from_dict(dic).T
pylint_df['TOTAL_PYLINT'] = pylint_df.sum(axis=1)

# %%
pylint_df
# Out:
#                                      I     R     C     W     E  F  \
# alt-model-checkpoint-1.0.0           0     1    14     2     6  0
# bigchaindb_driver-0.5.1              0    35   141    41    63  0
# birdhousebuilder.recipe.nginx-0.1.4  0     2    64     6     7  0
# bise.theme-1.20.1                    0    29   155    44    86  0
# bbcode-1.0.8                         0    11    33    19     0  0
# aiida-core-0.12.2                    0  1768  9248  3244   789  0
# allennlp-0.6.0                       0    81  2149    49  1369  0
# bok_choy-0.5.0                       0     9    37     4    14  0
# ansigenome-0.5.6                     0    18    60    61     3  0
# autobahn-0.14.1                      0   319  2922   686   298  0
# alexandra-0.3.3                      0     2    20     4     4  0
# boss-cli-0.3.0                       0     3    31    19    19  0
# anncolvar-0.3                        0     4   548   405    37  0
# ...

# %%
# number of total issues
# number of test categories flagged
# number of low/medium/high for severity and confidence
# number of overlapping lines

# %%
## Preliminary explanation of bandit and pylint output
# bar chart with test names, types of errors
# pie chart for low/med/high severity and confidence
# for bandit: filter out low confidence

# %%
## Stats
# regression/correlation on number of pylint issues vs number of bandit issues 
# (if time; find covariates like program size)
# split by pylint category and bandit test name, severity level

# num high severity security issues = beta_1 * I + beta_2 * R + ... -> learn the betas (weights) for pylint categories
# then do this for specific categories of security issues - blaclist, subprocess, etc

# If time: PCA of matrix with bandit vs all the repos, do 6 clusters

# %%
# I did the a's and b's and saved them on my local machine into 'banditcsv' and 'pylintcsv'
# For each python project: process the bandit file, process the pylint file

# %%
# also add total number of I + R + C..

# %%
# One dataframe
# Each row is a python project (Benchmark)
# Columns: I, R, C, ..., I+R+..., High severity, ..., High confidence, ..., B101, B102, ...
# Before building this df, throw out all the low confidence

# %%
# Loop through directory
# First bandit, and define row names by the benchmark names
# Then pylint, and match it up with existing row names
# Or vice versa
